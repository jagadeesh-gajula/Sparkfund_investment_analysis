# %%
import pandas as pd

company=pd.read_csv('company.csv',delimiter='\t')
rounds2=pd.read_csv('rounds2.csv',encoding='iso-8859-1')
mapping=pd.read_csv('mapping.csv',encoding='iso-8859-1')

# %%
import requests
from bs4 import BeautifulSoup
import urllib

page = urllib.request.urlopen('https://en.wikipedia.org/wiki/List_of_territorial_entities_where_English_is_an_official_language')
data=page.read()
soup=BeautifulSoup(data,'html.parser')
table=soup.findAll('tbody')
table[1]
# Out:
# <tbody><tr>
# <th>Nr
# </th>
# <th>Country
# </th>
# <th>Region
# </th>
# <th>Population<sup class="reference plainlinks nourlexpansion" id="ref_population"><a href="#endnote_population">1</a></sup>
# </th>
# <th>Primary language?
# </th></tr>
# <tr>
# <td>1</td>
# ...

# %%
import pandas as pd
tables = pd.read_html("https://en.wikipedia.org/wiki/List_of_territorial_entities_where_English_is_an_official_language")

table=tables[1]
pd.DataFrame(table)
# Out:
#        0                                     1                      2  \
# 0     Nr                               Country                 Region
# 1      1                Antigua and Barbuda[2]              Caribbean
# 2      2                            Bahamas[2]              Caribbean
# 3      3                           Barbados[3]              Caribbean
# 4      4                             Belize[4]        Central America
# 5      5                           Botswana[4]                 Africa
# 6      6                            Burundi[5]                 Africa
# 7      7                           Cameroon[2]                 Africa
# 8      8                             Canada[2]          North America
# 9      9                     Cook Islands14[2]                Oceania
# 10    10                           Dominica[2]              Caribbean
# 11    11                           Eswatini[2]                 Africa
# ...
